# %% [markdown]
# Exploratory Data Analysis

# %%
import sys
import os
os.chdir('..')
sys.path.append(os.path.abspath('c:/Users/mama/Desktop/Week3/AlphaCare-Insurance-Solutions/scripts'))

# %%
from eda import missing_values_table, remove_rows_with_missing_values, fill_missing_values, plot_histograms, plot_bar_charts, univariate_analysis, plot_car_insurance_correlation_matrix, plot_scatter_car_insurance, car_insurance_analysis, plot_cover_type_distribution, analyze_geography_trends, plot_premium_by_geography, calculate_claim_frequency, plot_claim_frequency_distribution, claim_frequency_statistics, trend_analysis, plot_total_claims_trend, preprocess_and_group_by_month, analyze_customer_demographics

# %% [markdown]
# Data Summarization

# %%
import pandas as pd

# %%
df = pd.read_csv('c:/Users/mama/Desktop/Week3/AlphaCare-Insurance-Solutions/notebooks/MachineLearningRating_v3.txt', delimiter='|', encoding='utf-8')
# Out:
# C:\Users\mama\AppData\Local\Temp\ipykernel_7008\126188477.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('c:/Users/mama/Desktop/Week3/AlphaCare-Insurance-Solutions/notebooks/MachineLearningRating_v3.txt', delimiter='|', encoding='utf-8')

# %%
df
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
unique_values = df['PolicyID'].unique()
print(unique_values)
# Out:
# [12827 10874 10173 ... 22498   807 22854]

# %%
unique_count = df['PolicyID'].nunique()
print(f"Number of unique values in '{'PolicyID'}': {unique_count}")
# Out:
# Number of unique values in 'PolicyID': 7000

# %%
df.shape
# Out:
# (1000098, 52)

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
df.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
df.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %% [markdown]
# Data Quality Assesment

# %%
missing_values_df = missing_values_table(df)
print("Missing Values in df:")
print(missing_values_df)
# Out:
# Your selected dataframe has 52 columns.
# There are 22 columns that have missing values.
# Missing Values in df:
#                          Missing Values  % of Total Values    Dtype
# NumberOfVehiclesInFleet         1000098              100.0  float64
# CrossBorder                      999400               99.9   object
# CustomValueEstimate              779642               78.0  float64
# Converted                        641901               64.2   object
# Rebuilt                          641901               64.2   object
# WrittenOff                       641901               64.2   object
# NewVehicle                       153295               15.3   object
# Bank                             145961               14.6   object
# AccountType                       40232                4.0   object
# Gender                             9536                1.0   object
# MaritalStatus                      8259                0.8   object
# ...

# %%
df = df.drop('NumberOfVehiclesInFleet', axis=1)

# %%
df.shape
# Out:
# (1000098, 51)

# %%
columns_to_check = ['kilowatts', 'CapitalOutstanding', 'Gender']

# Use the function to remove rows with missing values in the specified columns
df = remove_rows_with_missing_values(df, columns_to_check)

# Display the cleaned DataFrame
print("\nDataFrame after Removing Rows with Missing Values in 'Age' or 'Salary':")
print(df)
# Out:
# DataFrame after Removing Rows with Missing Values in 'Age' or 'Salary':
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# ...

# %%
filling_methods = {


    'CrossBorder': 'mode',
    'Converted': 'mode',
    'Rebuilt': 'mode',
    'WrittenOff': 'mode',
    'NewVehicle': 'mode',
    'Bank': 'mode',
    'AccountType': 'mode',
    'MaritalStatus': 'mode',
   

    'CustomValueEstimate': 'mean',
   

        # Adding multiple columns for median imputation
}

# Apply the fill_missing_values function using the selected methods
df = fill_missing_values(df, filling_methods)

# Display the DataFrame after filling missing values
print("\nDataFrame after Filling Missing Values with Median:")
print(df)
# Out:
# c:\Users\mama\Desktop\Week3\AlphaCare-Insurance-Solutions\scripts\eda.py:61: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)
# c:\Users\mama\Desktop\Week3\AlphaCare-Insurance-Solutions\scripts\eda.py:59: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
missing_values_df = missing_values_table(df)
print("Missing Values in df:")
print(missing_values_df)
# Out:
# Your selected dataframe has 51 columns.
# There are 0 columns that have missing values.
# Missing Values in df:
# Empty DataFrame
# Columns: [Missing Values, % of Total Values, Dtype]
# Index: []

# %% [markdown]
# Here the data is cleaned

# %% [markdown]
# Outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Boxplot for 'TotalPremium' column
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['TotalPremium'], color='green')
plt.title('Boxplot of TotalPremium')
plt.show()

# %%
# Boxplot for 'TotalClaims' column
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['TotalClaims'], color='lightblue')
plt.title('Boxplot of TotalClaims')
plt.show()

# %% [markdown]
# ## Univariate analysis

# %%
# Define lists of numerical and categorical columns
numerical_columns = ['TotalPremium', 'TotalClaims', 'SumInsured', 'CalculatedPremiumPerTerm', 'kilowatts','mmcode' ]
categorical_columns = ['Gender', 'MaritalStatus', 'AccountType', 'LegalType', 'VehicleType', 'CoverType', 'make']

# Perform univariate analysis
univariate_analysis(df, numerical_columns, categorical_columns)
# Out:
# Plotting Histograms for Numerical Variables:
# Plotting Bar Charts for Categorical Variables:

# %% [markdown]
# ## Bivarient or Multiple Analysis

# %%
car_insurance_analysis(df)
# Out:
# Analyzing relationship between TotalPremium and TotalClaims by VehicleType...
# Calculating correlation matrix for car insurance variables...

# %% [markdown]
# ## Data Comparision

# %%
province_summary = analyze_geography_trends(df, 'Province')
print(province_summary.head())
# Out:
#         Province  AvgPremium  MedianPremium  TotalPremiumSum  AvgClaims  \
# 0   Eastern Cape   70.546672       2.440702     2.140104e+06  44.713432
# 1     Free State   64.373780       3.592281     5.213632e+05  43.822975
# 2        Gauteng   60.196464       2.167018     2.322482e+07  74.873983
# 3  KwaZulu-Natal   78.600678       2.744123     1.320908e+07  85.100429
# 4        Limpopo   61.899038       3.172807     1.537324e+06  40.927553
#
#    MedianClaims  TotalClaimsSum MostCommonAutoMake  \
# 0           0.0    1.356427e+06             TOYOTA
# 1           0.0    3.549223e+05             TOYOTA
# 2           0.0    2.888766e+07             TOYOTA
# 3           0.0    1.430138e+07             TOYOTA
# 4           0.0    1.016477e+06             TOYOTA
#
#                        MostCommonCoverType
# 0                      Passenger Liability
# 1                               Windscreen
# 2                               Own Damage
# 3                              Third Party
# ...

# %%
plot_premium_by_geography(province_summary, 'Province')
# Out:
# c:\Users\mama\Desktop\Week3\AlphaCare-Insurance-Solutions\scripts\eda.py:206: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_by_col, y='AvgPremium', data=summary_df, palette='coolwarm')

# %%
plot_cover_type_distribution(df, 'Province')

# %%
claim_frequency = calculate_claim_frequency(df)

# %%
plot_claim_frequency_distribution(claim_frequency)

# %%
claim_frequency_statistics(claim_frequency)
# Out:
# count     6864.000000
# mean       144.231935
# std        226.587586
# min          1.000000
# 25%         60.000000
# 50%        100.000000
# 75%        150.000000
# max      10400.000000
# Name: ClaimFrequency, dtype: float64
# count     6864.000000
# mean       144.231935
# std        226.587586
# min          1.000000
# 25%         60.000000
# 50%        100.000000
# 75%        150.000000
# max      10400.000000
# Name: ClaimFrequency, dtype: float64

# %%
monthly_claims = preprocess_and_group_by_month(df)

# %%
plot_total_claims_trend(monthly_claims)

# %%
demographic_columns = ['Title', 'IsVATRegistered', 'Province', 'LegalType', 'VehicleType']
# Execute the analysis
analyze_customer_demographics(df, demographic_columns)
# Out:
# Analyzing Total Claims by Title
# c:\Users\mama\Desktop\Week3\AlphaCare-Insurance-Solutions\scripts\eda.py:371: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=demographic_col, y='TotalClaims', data=demographic_summary, palette='Blues_d')
# c:\Users\mama\Desktop\Week3\AlphaCare-Insurance-Solutions\scripts\eda.py:381: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=demographic_col, y='TotalClaims', data=df, palette='coolwarm')
# Analyzing Total Claims by IsVATRegistered
# c:\Users\mama\Desktop\Week3\AlphaCare-Insurance-Solutions\scripts\eda.py:371: FutureWarning:
#
# ...
